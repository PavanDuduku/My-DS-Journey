# %%
import pandas as pd

# Load the data
df = pd.read_csv('/Users/pavanduduku/UEL/Dissertation - 7010/2024-34-3/data/train_operational_readouts.csv', nrows=1000)  # Load only the first 1000 rows for quick inspection

# View the first 5 rows
print(df.head())
# Get summary statistics
print(df.describe())
